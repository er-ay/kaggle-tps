# %% [markdown]
# # Libraries

# %%
import numpy as np
import pandas as pd
import optuna
from lightgbm import LGBMClassifier
from sklearn.metrics import log_loss
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
train_set = pd.read_csv("../input/tabular-playground-series-jun-2021/train.csv")
test_set = pd.read_csv("../input/tabular-playground-series-jun-2021/test.csv")

train = train_set.copy()
test = test_set.copy()

train.drop("id",axis=1,inplace=True)
test.drop("id",axis=1,inplace=True)

train["sum"] = train.sum(axis=1)
test["sum"] = test.sum(axis=1)

X = np.array(train.drop("target",axis=1))
y = np.array(train["target"])
le = LabelEncoder()
y = le.fit_transform(np.ravel(y))

# %% [markdown]
# # Defining Model

# %%
def objective(trial,X,y):
    
    X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2,random_state=17)
    params = {
        'reg_alpha' : trial.suggest_loguniform('reg_alpha' , 1 , 100),
        'reg_lambda' : trial.suggest_loguniform('reg_lambda' , 500 , 1000),
        'num_leaves' : trial.suggest_int('num_leaves' , 90 , 150), 
        'learning_rate' : trial.suggest_float('learning_rate' , 0.01 , 0.5),
        'max_depth' : trial.suggest_int('max_depth' , 2 , 5),               
        'n_estimators' : trial.suggest_int('n_estimators' , 1 ,50000),
        'min_child_samples' : trial.suggest_int('min_child_samples' , 1 , 10),
        'min_child_weight' : trial.suggest_loguniform('min_child_weight' , 1e-3 , 2),
        'subsample' : trial.suggest_float('subsample' , 0.008 , 1.0),
        'colsample_bytree' : trial.suggest_float('colsample_bytree' , 0.01 , 0.3)
    }
    lgb = LGBMClassifier(**params)  
    lgb.fit(X_train,y_train,eval_set=[(X_val,y_val)],eval_metric='multi_logloss',early_stopping_rounds=50, verbose=False)
        
    y_pred = lgb.predict_proba(X_val)
 
    log_loss_ = log_loss(y_val, y_pred)
    
    return log_loss_

# %% [markdown]
# # Optuna

# %%
study = optuna.create_study(direction='minimize')
study.optimize(lambda trial: objective(trial,X,y), n_trials=30)
print('Number of finished trials:', len(study.trials))
print('Best trial:', study.best_trial.params)
# Out:
# [I 2021-06-02 18:34:58,849] A new study created in memory with name: no-name-42b317a3-1ee5-4a72-b90d-c0f8dc4e1e36
# [I 2021-06-02 18:35:23,409] Trial 0 finished with value: 1.7430048147978034 and parameters: {'reg_alpha': 29.956194265766857, 'reg_lambda': 943.8232016182603, 'num_leaves': 142, 'learning_rate': 0.36479818492146915, 'max_depth': 5, 'n_estimators': 13856, 'min_child_samples': 10, 'min_child_weight': 0.5437237107924228, 'subsample': 0.5047597067332052, 'colsample_bytree': 0.15291587793848427}. Best is trial 0 with value: 1.7430048147978034.
# [I 2021-06-02 18:35:58,215] Trial 1 finished with value: 1.7428133692169856 and parameters: {'reg_alpha': 3.059330902415478, 'reg_lambda': 597.5602343386747, 'num_leaves': 130, 'learning_rate': 0.20635023151564869, 'max_depth': 2, 'n_estimators': 23159, 'min_child_samples': 1, 'min_child_weight': 0.0296888506460925, 'subsample': 0.3250969033933623, 'colsample_bytree': 0.0624182435053279}. Best is trial 1 with value: 1.7428133692169856.
# [I 2021-06-02 18:36:30,778] Trial 2 finished with value: 1.74296767503173 and parameters: {'reg_alpha': 1.0911938402075088, 'reg_lambda': 673.8792706811486, 'num_leaves': 116, 'learning_rate': 0.2822926431041207, 'max_depth': 2, 'n_estimators': 12966, 'min_child_samples': 10, 'min_child_weight': 0.0043258475949717375, 'subsample': 0.47749851209316463, 'colsample_bytree': 0.2180113412753313}. Best is trial 1 with value: 1.7428133692169856.
# [I 2021-06-02 18:37:59,019] Trial 3 finished with value: 1.7421342469097707 and parameters: {'reg_alpha': 62.39650493100767, 'reg_lambda': 707.1603547107801, 'num_leaves': 136, 'learning_rate': 0.2476855535408066, 'max_depth': 5, 'n_estimators': 6663, 'min_child_samples': 2, 'min_child_weight': 0.04619738786902272, 'subsample': 0.1451076495463059, 'colsample_bytree': 0.13205848666170816}. Best is trial 3 with value: 1.7421342469097707.
# [I 2021-06-02 18:39:20,625] Trial 4 finished with value: 1.7415530729071838 and parameters: {'reg_alpha': 24.648414773594002, 'reg_lambda': 705.9079744026114, 'num_leaves': 116, 'learning_rate': 0.0784629923294019, 'max_depth': 2, 'n_estimators': 30060, 'min_child_samples': 10, 'min_child_weight': 0.8699833896612201, 'subsample': 0.509618429253323, 'colsample_bytree': 0.066914758945058}. Best is trial 4 with value: 1.7415530729071838.
# [I 2021-06-02 18:39:46,827] Trial 5 finished with value: 1.7431374972266502 and parameters: {'reg_alpha': 2.0195229209246475, 'reg_lambda': 813.8850531045342, 'num_leaves': 118, 'learning_rate': 0.32057223130141627, 'max_depth': 2, 'n_estimators': 2076, 'min_child_samples': 6, 'min_child_weight': 0.0023926326865532864, 'subsample': 0.9233786648288732, 'colsample_bytree': 0.16886007454540095}. Best is trial 4 with value: 1.7415530729071838.
# [I 2021-06-02 18:40:23,369] Trial 6 finished with value: 1.7424966926132623 and parameters: {'reg_alpha': 1.888963643419416, 'reg_lambda': 563.1253438083695, 'num_leaves': 106, 'learning_rate': 0.2895365310891118, 'max_depth': 2, 'n_estimators': 35931, 'min_child_samples': 8, 'min_child_weight': 0.002944678055659333, 'subsample': 0.1296764042455538, 'colsample_bytree': 0.1779964281912268}. Best is trial 4 with value: 1.7415530729071838.
# [I 2021-06-02 18:42:55,527] Trial 7 finished with value: 1.7397872037002744 and parameters: {'reg_alpha': 6.369417853951049, 'reg_lambda': 977.5200259397533, 'num_leaves': 112, 'learning_rate': 0.033295298708990874, 'max_depth': 5, 'n_estimators': 27067, 'min_child_samples': 1, 'min_child_weight': 0.5048354430526332, 'subsample': 0.9895697933450037, 'colsample_bytree': 0.12280480368900834}. Best is trial 7 with value: 1.7397872037002744.
# [I 2021-06-02 18:43:24,313] Trial 8 finished with value: 1.7430524462160377 and parameters: {'reg_alpha': 13.875302921195114, 'reg_lambda': 818.4087696901139, 'num_leaves': 126, 'learning_rate': 0.3747054508996634, 'max_depth': 3, 'n_estimators': 2142, 'min_child_samples': 2, 'min_child_weight': 0.0018179775548978763, 'subsample': 0.920336765138162, 'colsample_bytree': 0.20240014752672977}. Best is trial 7 with value: 1.7397872037002744.
# [I 2021-06-02 18:44:32,834] Trial 9 finished with value: 1.7431364682486186 and parameters: {'reg_alpha': 42.01833379671553, 'reg_lambda': 637.4955029181556, 'num_leaves': 130, 'learning_rate': 0.4362721322849827, 'max_depth': 5, 'n_estimators': 12630, 'min_child_samples': 7, 'min_child_weight': 1.719902471102915, 'subsample': 0.899432271027375, 'colsample_bytree': 0.029498407713323307}. Best is trial 7 with value: 1.7397872037002744.
# [I 2021-06-02 18:49:24,078] Trial 10 finished with value: 1.7403185809168735 and parameters: {'reg_alpha': 5.8553424531842495, 'reg_lambda': 962.2456324075398, 'num_leaves': 90, 'learning_rate': 0.019914887457560575, 'max_depth': 4, 'n_estimators': 47868, 'min_child_samples': 4, 'min_child_weight': 0.1544992620653901, 'subsample': 0.6980801571614768, 'colsample_bytree': 0.2964919180354536}. Best is trial 7 with value: 1.7397872037002744.
# [I 2021-06-02 18:54:39,740] Trial 11 finished with value: 1.7403818884904194 and parameters: {'reg_alpha': 5.938092603145764, 'reg_lambda': 997.5772023237819, 'num_leaves': 91, 'learning_rate': 0.01943288473058832, 'max_depth': 4, 'n_estimators': 48731, 'min_child_samples': 4, 'min_child_weight': 0.17847170400073237, 'subsample': 0.719308703379333, 'colsample_bytree': 0.28908140614418315}. Best is trial 7 with value: 1.7397872037002744.
# [I 2021-06-02 18:55:35,948] Trial 12 finished with value: 1.7409607532129328 and parameters: {'reg_alpha': 8.846698466044456, 'reg_lambda': 890.3726145813537, 'num_leaves': 92, 'learning_rate': 0.11639640518749642, 'max_depth': 4, 'n_estimators': 49083, 'min_child_samples': 4, 'min_child_weight': 0.1670332778534313, 'subsample': 0.7307558667145373, 'colsample_bytree': 0.2946514032180011}. Best is trial 7 with value: 1.7397872037002744.
# [I 2021-06-02 18:58:43,152] Trial 13 finished with value: 1.7398469319481071 and parameters: {'reg_alpha': 4.520711310556773, 'reg_lambda': 987.5057425378473, 'num_leaves': 101, 'learning_rate': 0.023706860903591892, 'max_depth': 4, 'n_estimators': 38619, 'min_child_samples': 4, 'min_child_weight': 0.2167646060787119, 'subsample': 0.7202319386597731, 'colsample_bytree': 0.11515202867247516}. Best is trial 7 with value: 1.7397872037002744.
# [I 2021-06-02 18:59:19,203] Trial 14 finished with value: 1.740971624583066 and parameters: {'reg_alpha': 4.159973239192447, 'reg_lambda': 861.6055914704656, 'num_leaves': 105, 'learning_rate': 0.15123010472974246, 'max_depth': 3, 'n_estimators': 38837, 'min_child_samples': 1, 'min_child_weight': 0.5199839963411416, 'subsample': 0.8007076387985641, 'colsample_bytree': 0.09839156263811763}. Best is trial 7 with value: 1.7397872037002744.
# [I 2021-06-02 19:06:06,640] Trial 15 finished with value: 1.7397873354608349 and parameters: {'reg_alpha': 14.03553383381321, 'reg_lambda': 772.9429685847167, 'num_leaves': 106, 'learning_rate': 0.011337724485344028, 'max_depth': 4, 'n_estimators': 25191, 'min_child_samples': 3, 'min_child_weight': 0.030533536972276804, 'subsample': 0.6095888117822252, 'colsample_bytree': 0.11936113203347352}. Best is trial 7 with value: 1.7397872037002744.
# [I 2021-06-02 19:07:06,640] Trial 16 finished with value: 1.7397614774777241 and parameters: {'reg_alpha': 14.066386297492933, 'reg_lambda': 782.6513660266065, 'num_leaves': 110, 'learning_rate': 0.08091591904311343, 'max_depth': 5, 'n_estimators': 22091, 'min_child_samples': 2, 'min_child_weight': 0.014167803972043104, 'subsample': 0.9981917429044114, 'colsample_bytree': 0.08909643303979979}. Best is trial 16 with value: 1.7397614774777241.
# [I 2021-06-02 19:09:20,966] Trial 17 finished with value: 1.742792860271923 and parameters: {'reg_alpha': 10.651827324911778, 'reg_lambda': 791.1825352558604, 'num_leaves': 111, 'learning_rate': 0.0778761532164732, 'max_depth': 5, 'n_estimators': 20484, 'min_child_samples': 1, 'min_child_weight': 0.010307864966467687, 'subsample': 0.9488765255531351, 'colsample_bytree': 0.026415171355485115}. Best is trial 16 with value: 1.7397614774777241.
# [I 2021-06-02 19:10:07,433] Trial 18 finished with value: 1.7418879958679878 and parameters: {'reg_alpha': 21.773190035496835, 'reg_lambda': 891.4968061284028, 'num_leaves': 98, 'learning_rate': 0.1985135033414795, 'max_depth': 5, 'n_estimators': 28533, 'min_child_samples': 2, 'min_child_weight': 0.011294004327616477, 'subsample': 0.9822458421868892, 'colsample_bytree': 0.07854885024728003}. Best is trial 16 with value: 1.7397614774777241.
# [I 2021-06-02 19:12:01,098] Trial 19 finished with value: 1.7414309034422837 and parameters: {'reg_alpha': 95.4607367967033, 'reg_lambda': 728.2272693202386, 'num_leaves': 150, 'learning_rate': 0.08219795687543908, 'max_depth': 5, 'n_estimators': 20314, 'min_child_samples': 3, 'min_child_weight': 0.06576082843401501, 'subsample': 0.8267345154370054, 'colsample_bytree': 0.25436367792312575}. Best is trial 16 with value: 1.7397614774777241.
# [I 2021-06-02 19:12:48,366] Trial 20 finished with value: 1.7413703925475366 and parameters: {'reg_alpha': 8.169436139661295, 'reg_lambda': 518.9580774706001, 'num_leaves': 123, 'learning_rate': 0.14136435768892647, 'max_depth': 3, 'n_estimators': 32622, 'min_child_samples': 5, 'min_child_weight': 0.011244476374688003, 'subsample': 0.2918267038547433, 'colsample_bytree': 0.044223055244325564}. Best is trial 16 with value: 1.7397614774777241.
# [I 2021-06-02 19:20:30,212] Trial 21 finished with value: 1.7400099424688844 and parameters: {'reg_alpha': 17.497410294113237, 'reg_lambda': 780.6296053286285, 'num_leaves': 110, 'learning_rate': 0.012696563185311118, 'max_depth': 4, 'n_estimators': 26791, 'min_child_samples': 3, 'min_child_weight': 0.02619301861040005, 'subsample': 0.6165173650667888, 'colsample_bytree': 0.1313850396924613}. Best is trial 16 with value: 1.7397614774777241.
# [I 2021-06-02 19:22:14,849] Trial 22 finished with value: 1.7398187971006638 and parameters: {'reg_alpha': 13.366689203792486, 'reg_lambda': 761.5773058014114, 'num_leaves': 97, 'learning_rate': 0.045407833786175994, 'max_depth': 5, 'n_estimators': 18808, 'min_child_samples': 3, 'min_child_weight': 0.07712121755495346, 'subsample': 0.8373940754234253, 'colsample_bytree': 0.09381468914790263}. Best is trial 16 with value: 1.7397614774777241.
# [I 2021-06-02 19:24:03,000] Trial 23 finished with value: 1.7402456985552508 and parameters: {'reg_alpha': 34.321533052053674, 'reg_lambda': 657.2465126308358, 'num_leaves': 111, 'learning_rate': 0.06077214811929926, 'max_depth': 4, 'n_estimators': 24040, 'min_child_samples': 1, 'min_child_weight': 0.017909854850674645, 'subsample': 0.9933762861437423, 'colsample_bytree': 0.13568800355163307}. Best is trial 16 with value: 1.7397614774777241.
# [I 2021-06-02 19:25:02,548] Trial 24 finished with value: 1.740905396984682 and parameters: {'reg_alpha': 16.894743739544037, 'reg_lambda': 854.5847677217529, 'num_leaves': 105, 'learning_rate': 0.1161653652550604, 'max_depth': 5, 'n_estimators': 16568, 'min_child_samples': 2, 'min_child_weight': 0.006590279978506407, 'subsample': 0.5857935010764663, 'colsample_bytree': 0.10080415222885061}. Best is trial 16 with value: 1.7397614774777241.
# [I 2021-06-02 19:25:32,278] Trial 25 finished with value: 1.7411522144548388 and parameters: {'reg_alpha': 7.06304797289097, 'reg_lambda': 742.2681822859751, 'num_leaves': 112, 'learning_rate': 0.18460634655372224, 'max_depth': 4, 'n_estimators': 33267, 'min_child_samples': 3, 'min_child_weight': 0.08706845794967583, 'subsample': 0.3607059575105681, 'colsample_bytree': 0.11424776298827215}. Best is trial 16 with value: 1.7397614774777241.
# [I 2021-06-02 19:35:46,342] Trial 26 finished with value: 1.7404974150419708 and parameters: {'reg_alpha': 12.861566435929353, 'reg_lambda': 921.9352229489435, 'num_leaves': 120, 'learning_rate': 0.010086832366429963, 'max_depth': 3, 'n_estimators': 24496, 'min_child_samples': 5, 'min_child_weight': 0.025808497088352582, 'subsample': 0.042186732024879325, 'colsample_bytree': 0.15916357785981844}. Best is trial 16 with value: 1.7397614774777241.
# [I 2021-06-02 19:36:36,509] Trial 27 finished with value: 1.7411572273586267 and parameters: {'reg_alpha': 4.145983499481042, 'reg_lambda': 833.7106238452609, 'num_leaves': 100, 'learning_rate': 0.10793997284180563, 'max_depth': 5, 'n_estimators': 8939, 'min_child_samples': 2, 'min_child_weight': 0.005810149112999601, 'subsample': 0.8482132486291885, 'colsample_bytree': 0.19700540095946623}. Best is trial 16 with value: 1.7397614774777241.
# [I 2021-06-02 19:38:58,337] Trial 28 finished with value: 1.7456900609304096 and parameters: {'reg_alpha': 2.667979038421105, 'reg_lambda': 603.2871168080916, 'num_leaves': 106, 'learning_rate': 0.049522261008508595, 'max_depth': 4, 'n_estimators': 40762, 'min_child_samples': 1, 'min_child_weight': 0.001047282687324623, 'subsample': 0.9992552503404482, 'colsample_bytree': 0.010356708678642065}. Best is trial 16 with value: 1.7397614774777241.
# [I 2021-06-02 19:39:42,153] Trial 29 finished with value: 1.7408222818649712 and parameters: {'reg_alpha': 40.66827519464725, 'reg_lambda': 692.5783670937129, 'num_leaves': 114, 'learning_rate': 0.16747089057151954, 'max_depth': 5, 'n_estimators': 15969, 'min_child_samples': 3, 'min_child_weight': 0.5095929061275701, 'subsample': 0.46536249193144597, 'colsample_bytree': 0.14700726808814357}. Best is trial 16 with value: 1.7397614774777241.
# Number of finished trials: 30
# Best trial: {'reg_alpha': 14.066386297492933, 'reg_lambda': 782.6513660266065, 'num_leaves': 110, 'learning_rate': 0.08091591904311343, 'max_depth': 5, 'n_estimators': 22091, 'min_child_samples': 2, 'min_child_weight': 0.014167803972043104, 'subsample': 0.9981917429044114, 'colsample_bytree': 0.08909643303979979}

# %%
best_params = study.best_trial.params
best_params
# Out:
# {'reg_alpha': 14.066386297492933,
#  'reg_lambda': 782.6513660266065,
#  'num_leaves': 110,
#  'learning_rate': 0.08091591904311343,
#  'max_depth': 5,
#  'n_estimators': 22091,
#  'min_child_samples': 2,
#  'min_child_weight': 0.014167803972043104,
#  'subsample': 0.9981917429044114,
#  'colsample_bytree': 0.08909643303979979}

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2,random_state=17)

# %%
lgb = LGBMClassifier(**best_params)
lgb.fit(X_train, y_train)
# Out:
# LGBMClassifier(colsample_bytree=0.08909643303979979,
#                learning_rate=0.08091591904311343, max_depth=5,
#                min_child_samples=2, min_child_weight=0.014167803972043104,
#                n_estimators=22091, num_leaves=110, reg_alpha=14.066386297492933,
#                reg_lambda=782.6513660266065, subsample=0.9981917429044114)

# %%
y_pred = lgb.predict_proba(X_val)
loss = log_loss(y_val, y_pred)
loss
# Out:
# 1.7459418111813605

# %%
y_test = lgb.predict_proba(test)
y_test
# Out:
# array([[0.07170752, 0.40732525, 0.15684798, ..., 0.02112199, 0.03381467,
#         0.11468468],
#        [0.03918568, 0.08120554, 0.06402575, ..., 0.09727472, 0.34078973,
#         0.11627944],
#        [0.01963153, 0.03393188, 0.02818354, ..., 0.02797627, 0.09937416,
#         0.06457668],
#        ...,
#        [0.08806375, 0.29096711, 0.1321415 , ..., 0.0367138 , 0.10852454,
#         0.13111658],
#        [0.04325971, 0.01918469, 0.01363984, ..., 0.07392011, 0.36354676,
#         0.10702745],
#        [0.05210888, 0.05773908, 0.06166756, ..., 0.09269002, 0.2630184 ,
#         0.15562036]])

# %%
result = pd.DataFrame(index=test_set["id"], data={"Class_1": y_test[:,0],"Class_2": y_test[:,1],"Class_3": y_test[:,2],"Class_4": y_test[:,3],"Class_5": y_test[:,4],
                                                 "Class_6": y_test[:,5],"Class_7": y_test[:,6],"Class_8": y_test[:,7],"Class_9": y_test[:,8]})
result.head()
# Out:
#          Class_1   Class_2   Class_3   Class_4   Class_5   Class_6   Class_7  \
# id
# 200000  0.071708  0.407325  0.156848  0.028704  0.013090  0.152704  0.021122
# 200001  0.039186  0.081206  0.064026  0.011419  0.010820  0.239000  0.097275
# 200002  0.019632  0.033932  0.028184  0.010671  0.005926  0.709729  0.027976
# 200003  0.046524  0.135671  0.082438  0.056164  0.016266  0.190736  0.082790
# 200004  0.046190  0.108180  0.093111  0.032607  0.015512  0.217985  0.061990
#
#          Class_8   Class_9
# id
# 200000  0.033815  0.114685
# 200001  0.340790  0.116279
# 200002  0.099374  0.064577
# 200003  0.205534  0.183877
# 200004  0.282162  0.142263

# %%
sub = result.to_csv("sub.csv")
